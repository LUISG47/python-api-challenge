# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import time
import json

# Import API key
from api_keys import geoapify_key
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1081'>
#   <div id="f579a6b7-fc78-45e2-9ba9-a5dddc28cb32" data-root-id="p1081" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0  port-aux-francais -49.3500   70.2167      2.42        76
# 1        1          grytviken -54.2811  -36.5092      1.88        59
# 2        2  wailua homesteads  22.0669 -159.3780     25.44        79
# 3        3               roma  43.2128  -75.4557      8.71        91
# 4        4      blackmans bay -43.0167  147.3167     21.52        36
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        8.13      TF  1730517895
# 1          18        3.10      GS  1730517896
# 2          75        7.72      US  1730517897
# 3         100        6.17      US  1730517900
# 4         100        1.79      AU  1730517901

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
 #Set the geographical coordinates for Sydney, Australia
latitude = -33.8698439
longitude = 151.2082848

# Set the parameters for the type of place
categories = "catering.restaurant"
conditions = "vegetarian"
radius = 8000

# Set the parameters for the type of search
filters = f"circle:{longitude},{latitude},{radius}"
bias = f"proximity:{longitude},{latitude}"
limit = 20

# set up a parameters dictionary
params = {
    "categories":categories,
    "conditions":conditions,
    "limit":limit,
    "filter":filters,
    "bias":bias,
    "apiKey":geoapify_key    
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# run a request using our params dictionary
response = requests.get(base_url, params=params)


# convert response to json
places_data = response.json()

# Print the name and address of the first restaurant that appears
print(places_data["features"][0]["properties"]["name"])
print(places_data["features"][0]["properties"]["address_line2"])
# Out:
# Macchiato
# 338 Pitt Street, Sydney NSW 2000, Australia

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE

map_plot = city_data_df.hvplot.scatter(
    x='Lng', 
    y='Lat', 
    size='Humidity', 
    color='Humidity', 
    alpha=0.5,
    title='City Humidity Levels',
    xlabel='Longitude',
    ylabel='Latitude',
)

# Display the map
map_plot
# Out:
# :Scatter   [Lng]   (Lat,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE

# Drop any rows with null values
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE


# Modify the condition based on your specific criteria
filtered_cities_df = city_data_df[city_data_df['Humidity'] > 30]

# Drop any rows with null values
filtered_cities_df = filtered_cities_df.dropna()

filtered_cities_df.head(15)
# Out:
#     City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 0         0   port-aux-francais -49.3500   70.2167      2.42        76
# 1         1           grytviken -54.2811  -36.5092      1.88        59
# 2         2   wailua homesteads  22.0669 -159.3780     25.44        79
# 3         3                roma  43.2128  -75.4557      8.71        91
# 4         4       blackmans bay -43.0167  147.3167     21.52        36
# 6         6               tiksi  71.6872  128.8694    -24.11       100
# 7         7  humberto de campos  -2.5983  -43.4611     23.84        89
# 8         8          isafjordur  66.0755  -23.1240     -0.96        84
# 9         9              albany  42.6001  -73.9662     11.47        64
# 10       10           flin flon  54.7682 -101.8650     -0.40        77
# 11       11         chake chake  -5.2459   39.7666     24.60        84
# 12       12            tazovsky  67.4667   78.7000     -6.60        92
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE



# Use the Pandas copy function to create DataFrame called hotel_df
hotel_df = filtered_cities_df.copy()

# Select relevant columns: City, Country, Latitude, Longitude, and Humidity
hotel_df = hotel_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']]

# Add an empty column, "Hotel Name," to the DataFrame
hotel_df['Hotel Name'] = ''


hotel_df.head(20)
# Out:
#                   City Country      Lat       Lng  Humidity Hotel Name
# 0    port-aux-francais      TF -49.3500   70.2167        76
# 1            grytviken      GS -54.2811  -36.5092        59
# 2    wailua homesteads      US  22.0669 -159.3780        79
# 3                 roma      US  43.2128  -75.4557        91
# 4        blackmans bay      AU -43.0167  147.3167        36
# 6                tiksi      RU  71.6872  128.8694       100
# 7   humberto de campos      BR  -2.5983  -43.4611        89
# 8           isafjordur      IS  66.0755  -23.1240        84
# 9               albany      US  42.6001  -73.9662        64
# 10           flin flon      CA  54.7682 -101.8650        77
# 11         chake chake      TZ  -5.2459   39.7666        84
# 12            tazovsky      RU  67.4667   78.7000        92
# 13          georgetown      MY   5.4112  100.3354        75
# 14            bilibino      RU  68.0546  166.4372        95
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
    # Set base URL
base_url = "https://api.geoapify.com/v2/places"
    
    # Make and API request using the params dictionary
response = requests.get(base_url, params=params)

    # Convert the API response to JSON format
name_address = response.json()
name_address
# Out:
# {'statusCode': 400,
#  'error': 'Bad Request',
#  'message': '"filter[0]" does not match any of the allowed types'}

# %%
# Set the geographical coordinates for Sydney, Australia
latitude = -33.8698439
longitude = 151.2082848

# Set the parameters for the type of place
categories = "catering.restaurant"
conditions = "vegetarian"
radius = 8000

# Set the parameters for the type of search
filters = f"circle:{longitude},{latitude},{radius}"
bias = f"proximity:{longitude},{latitude}"
limit = 20

# set up a parameters dictionary
params = {
    "categories":categories,
    "conditions":conditions,
    "limit":limit,
    "filter":filters,
    "bias":bias,
    "apiKey":geoapify_key    
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# run a request using our params dictionary
response = requests.get(base_url, params=params)


# convert response to json
places_data = response.json()

places_data
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Macchiato',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Council of the City of Sydney',
#     'postcode': '2000',
#     'district': 'Koreatown',
#     'suburb': 'Sydney',
#     'street': 'Pitt Street',
#     'housenumber': '338',
#     'lon': 151.2080336,
#     'lat': -33.8764809,
#     'state_code': 'NSW',
#     'formatted': 'Macchiato, 338 Pitt Street, Sydney NSW 2000, Australia',
#     'address_line1': 'Macchiato',
#     'address_line2': '338 Pitt Street, Sydney NSW 2000, Australia',
#     'categories': ['catering',
#      'catering.restaurant',
#      'catering.restaurant.pizza',
#      'vegetarian',
#      'wheelchair',
#      'wheelchair.limited'],
#     'details': ['details.catering', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
# ...

# %%
base_url = "https://api.geoapify.com/v2/places"
    
    # Make and API request using the params dictionary
response = requests.get(base_url, params=params)
response
# Out:
# <Response [200]>

# %%
    # Set base URL
base_url = "https://api.geoapify.com/v2/places"
    
    # Make and API request using the params dictionary
response = requests.get(base_url, params=params)

    # Convert the API response to JSON format
name_address = response.json()

name_address["features"][0]["properties"]["name"]
# Out:
# 'Macchiato'

# %%
# Function to get hotel categories
def get_hotel_category():
    category_url = "https://api.geoapify.com/v1/categories"
    response = requests.get(category_url, params={"apiKey": geoapify_key})

    if response.status_code == 200:
        categories = response.json()
        # Assuming you want the first hotel category as an example
        for category in categories.get("features", []):
            if category["properties"]["name"].lower() == "hotel":
                return category["properties"]["name"]
    return None




# Set parameters to search for a hotel
radius = 10000
hotel_category = get_hotel_category()
params = {
    "apiKey": geoapify_key,  # Your Geoapify API key
    "filter":  "",  # Filter for hotel category
    "bias": "",  # Placeholder for biasing results to nearby coordinates
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row['Lat']
    lng = row['Lng']
    
    # Add the current city's latitude and longitude to the params dictionary
    params["bias"] = f"proximity:{lng},{lat}"
    params["filter"] = f"category:{hotel_category}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"
    
    # Make and API request using the params dictionary
    response = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = response.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")
    time.sleep(1)
    
# Display sample data
hotel_df
# Out:
# Starting hotel search
# port-aux-francais - nearest hotel: No hotel found
# grytviken - nearest hotel: No hotel found
# wailua homesteads - nearest hotel: No hotel found
# roma - nearest hotel: No hotel found
# blackmans bay - nearest hotel: No hotel found
# tiksi - nearest hotel: No hotel found
# humberto de campos - nearest hotel: No hotel found
# isafjordur - nearest hotel: No hotel found
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 57
#      55     # Log the search results
#      56     print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")
# ---> 57     time.sleep(1)
#      59 # Display sample data
#      60 hotel_df
#
# KeyboardInterrupt:

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE

# Configure the map plot
map_plot = hotel_df.hvplot.points(
    x='Lng', 
    y='Lat', 
    size='Humidity',               # Size of the point based on humidity
    color='Humidity',              # Color based on humidity
    alpha=0.6,                    # Transparency level
    title='City Locations with Humidity Levels',
    xlabel='Longitude',
    ylabel='Latitude',
    legend=True,
    frame_width=800,              # Set the width of the plot
    frame_height=600              # Set the height of the plot
)

# Display the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
