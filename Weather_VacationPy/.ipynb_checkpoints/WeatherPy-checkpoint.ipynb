# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 581

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}&units=metric" 

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url)
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except Exception as e:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | fortuna
# Processing Record 2 of Set 1 | edinburgh of the seven seas
# Processing Record 3 of Set 1 | shenkursk
# Processing Record 4 of Set 1 | edmundston
# Processing Record 5 of Set 1 | inarajan village
# Processing Record 6 of Set 1 | adamstown
# Processing Record 7 of Set 1 | qaqortoq
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | ketchikan
# Processing Record 10 of Set 1 | osorno
# Processing Record 11 of Set 1 | altai
# Processing Record 12 of Set 1 | la passe
# Processing Record 13 of Set 1 | berriane
# Processing Record 14 of Set 1 | solnechnyy
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | udachny
# Processing Record 17 of Set 1 | las vegas
# Processing Record 18 of Set 1 | novaya igirma
# Processing Record 19 of Set 1 | waitangi
# Processing Record 20 of Set 1 | kodiak
# Processing Record 21 of Set 1 | margaret river
# Processing Record 22 of Set 1 | sitka
# Processing Record 23 of Set 1 | agat village
# Processing Record 24 of Set 1 | itoman
# Processing Record 25 of Set 1 | kailua-kona
# Processing Record 26 of Set 1 | tiksi
# Processing Record 27 of Set 1 | walvis bay
# Processing Record 28 of Set 1 | afaahiti
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | tivat
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | bulawayo
# Processing Record 33 of Set 1 | el granada
# Processing Record 34 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | la'ie
# Processing Record 37 of Set 1 | biltine
# Processing Record 38 of Set 1 | goundam
# Processing Record 39 of Set 1 | wailua homesteads
# Processing Record 40 of Set 1 | kurchatov
# Processing Record 41 of Set 1 | greymouth
# Processing Record 42 of Set 1 | tsiombe
# Processing Record 43 of Set 1 | tauranga
# Processing Record 44 of Set 1 | pimentel
# Processing Record 45 of Set 1 | chimore
# Processing Record 46 of Set 1 | hamilton
# Processing Record 47 of Set 1 | port-aux-francais
# Processing Record 48 of Set 1 | bethel
# Processing Record 49 of Set 1 | farasan
# Processing Record 50 of Set 1 | bardai
# Processing Record 0 of Set 2 | al kharijah
# Processing Record 1 of Set 2 | homer
# Processing Record 2 of Set 2 | puerto natales
# Processing Record 3 of Set 2 | georgetown
# Processing Record 4 of Set 2 | boyolangu
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | thayetmyo
# Processing Record 7 of Set 2 | enewetak
# Processing Record 8 of Set 2 | primero de enero
# Processing Record 9 of Set 2 | kone
# Processing Record 10 of Set 2 | papatowai
# Processing Record 11 of Set 2 | olonkinbyen
# Processing Record 12 of Set 2 | stanley
# Processing Record 13 of Set 2 | guayaramerin
# Processing Record 14 of Set 2 | dhidhdhoo
# Processing Record 15 of Set 2 | vadso
# Processing Record 16 of Set 2 | kendari
# Processing Record 17 of Set 2 | callao
# Processing Record 18 of Set 2 | huarmey
# Processing Record 19 of Set 2 | hithadhoo
# Processing Record 20 of Set 2 | tevriz
# Processing Record 21 of Set 2 | santa elena de uairen
# Processing Record 22 of Set 2 | bilibino
# Processing Record 23 of Set 2 | grytviken
# Processing Record 24 of Set 2 | longyearbyen
# Processing Record 25 of Set 2 | iskateley
# Processing Record 26 of Set 2 | constantia
# Processing Record 27 of Set 2 | chonchi
# Processing Record 28 of Set 2 | verdal
# Processing Record 29 of Set 2 | thompson
# Processing Record 30 of Set 2 | iqaluit
# Processing Record 31 of Set 2 | invercargill
# Processing Record 32 of Set 2 | richland center
# Processing Record 33 of Set 2 | wynyard
# Processing Record 34 of Set 2 | zangguy
# City not found. Skipping...
# Processing Record 35 of Set 2 | vila velha
# Processing Record 36 of Set 2 | san luis
# Processing Record 37 of Set 2 | vilyuchinsk
# Processing Record 38 of Set 2 | idri
# Processing Record 39 of Set 2 | cannonvale
# Processing Record 40 of Set 2 | college
# Processing Record 41 of Set 2 | marica
# Processing Record 42 of Set 2 | ilulissat
# Processing Record 43 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 44 of Set 2 | blackmans bay
# Processing Record 45 of Set 2 | remire-montjoly
# Processing Record 46 of Set 2 | inirida
# Processing Record 47 of Set 2 | antsiranana
# Processing Record 48 of Set 2 | copala
# Processing Record 49 of Set 2 | katsuren-haebaru
# Processing Record 0 of Set 3 | sandanski
# Processing Record 1 of Set 3 | palikir - national government center
# Processing Record 2 of Set 3 | barcelos
# Processing Record 3 of Set 3 | geraldton
# Processing Record 4 of Set 3 | new norfolk
# Processing Record 5 of Set 3 | hawaiian paradise park
# Processing Record 6 of Set 3 | santo antonio do ica
# Processing Record 7 of Set 3 | san agustin de valle fertil
# Processing Record 8 of Set 3 | east london
# Processing Record 9 of Set 3 | hakha
# Processing Record 10 of Set 3 | arno
# Processing Record 11 of Set 3 | egilsstadir
# Processing Record 12 of Set 3 | chibougamau
# Processing Record 13 of Set 3 | vorgashor
# Processing Record 14 of Set 3 | port alfred
# Processing Record 15 of Set 3 | dunedin
# Processing Record 16 of Set 3 | dzagam
# Processing Record 17 of Set 3 | mil'kovo
# Processing Record 18 of Set 3 | korop
# Processing Record 19 of Set 3 | sinabang
# Processing Record 20 of Set 3 | gaalkacyo
# Processing Record 21 of Set 3 | kerikeri
# Processing Record 22 of Set 3 | nemuro
# Processing Record 23 of Set 3 | carnarvon
# Processing Record 24 of Set 3 | kirkwall
# Processing Record 25 of Set 3 | labrador city
# Processing Record 26 of Set 3 | fale old settlement
# Processing Record 27 of Set 3 | srandakan
# Processing Record 28 of Set 3 | kenai
# Processing Record 29 of Set 3 | ingeniero jacobacci
# Processing Record 30 of Set 3 | north valley
# Processing Record 31 of Set 3 | batyrevo
# Processing Record 32 of Set 3 | tazacorte
# Processing Record 33 of Set 3 | jamestown
# Processing Record 34 of Set 3 | isafjordur
# Processing Record 35 of Set 3 | tazovsky
# Processing Record 36 of Set 3 | vavoua
# Processing Record 37 of Set 3 | nabire
# Processing Record 38 of Set 3 | saldanha
# Processing Record 39 of Set 3 | kataragama
# City not found. Skipping...
# Processing Record 40 of Set 3 | novyy urengoy
# Processing Record 41 of Set 3 | mirwah gorchani
# Processing Record 42 of Set 3 | menongue
# Processing Record 43 of Set 3 | tralee
# Processing Record 44 of Set 3 | greenville
# Processing Record 45 of Set 3 | champerico
# Processing Record 46 of Set 3 | klaksvik
# Processing Record 47 of Set 3 | sakaraha
# Processing Record 48 of Set 3 | talnakh
# Processing Record 49 of Set 3 | freetown
# Processing Record 0 of Set 4 | zouerate
# Processing Record 1 of Set 4 | tolanaro
# Processing Record 2 of Set 4 | pacific grove
# Processing Record 3 of Set 4 | devinuwara
# City not found. Skipping...
# Processing Record 4 of Set 4 | waitara
# Processing Record 5 of Set 4 | bredasdorp
# Processing Record 6 of Set 4 | pisco
# Processing Record 7 of Set 4 | port saint john's
# Processing Record 8 of Set 4 | machiques
# Processing Record 9 of Set 4 | cody
# Processing Record 10 of Set 4 | lompoc
# Processing Record 11 of Set 4 | kharp
# Processing Record 12 of Set 4 | newman
# Processing Record 13 of Set 4 | kyren
# Processing Record 14 of Set 4 | tidjikja
# Processing Record 15 of Set 4 | ocean city
# Processing Record 16 of Set 4 | flagstaff
# Processing Record 17 of Set 4 | port mathurin
# Processing Record 18 of Set 4 | nianzishan
# Processing Record 19 of Set 4 | campos belos
# Processing Record 20 of Set 4 | holualoa
# Processing Record 21 of Set 4 | bethlehem
# Processing Record 22 of Set 4 | saipan
# Processing Record 23 of Set 4 | amos
# Processing Record 24 of Set 4 | blythe
# Processing Record 25 of Set 4 | san patricio
# Processing Record 26 of Set 4 | luang prabang
# Processing Record 27 of Set 4 | caleta de carquin
# Processing Record 28 of Set 4 | bubaque
# Processing Record 29 of Set 4 | bainbridge
# Processing Record 30 of Set 4 | nadi
# Processing Record 31 of Set 4 | rio grande
# Processing Record 32 of Set 4 | utrik
# Processing Record 33 of Set 4 | west island
# Processing Record 34 of Set 4 | bela vista
# Processing Record 35 of Set 4 | severodvinsk
# Processing Record 36 of Set 4 | palmer
# Processing Record 37 of Set 4 | alofi
# Processing Record 38 of Set 4 | bac lieu
# Processing Record 39 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 40 of Set 4 | el calafate
# Processing Record 41 of Set 4 | igreja
# Processing Record 42 of Set 4 | kochubey
# Processing Record 43 of Set 4 | lezhe
# Processing Record 44 of Set 4 | mount pearl
# Processing Record 45 of Set 4 | pampierstad
# Processing Record 46 of Set 4 | pontianak
# Processing Record 47 of Set 4 | novi ligure
# Processing Record 48 of Set 4 | happy valley-goose bay
# Processing Record 49 of Set 4 | avarua
# Processing Record 0 of Set 5 | usinsk
# Processing Record 1 of Set 5 | kapa'a
# Processing Record 2 of Set 5 | mahina
# Processing Record 3 of Set 5 | raton
# Processing Record 4 of Set 5 | bovalino
# Processing Record 5 of Set 5 | vanimo
# Processing Record 6 of Set 5 | prince george
# Processing Record 7 of Set 5 | karratha
# Processing Record 8 of Set 5 | stornoway
# Processing Record 9 of Set 5 | broadstairs
# Processing Record 10 of Set 5 | sur
# Processing Record 11 of Set 5 | elin pelin
# Processing Record 12 of Set 5 | nkurenkuru
# City not found. Skipping...
# Processing Record 13 of Set 5 | whitehorse
# Processing Record 14 of Set 5 | bandon
# Processing Record 15 of Set 5 | chui
# Processing Record 16 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 17 of Set 5 | coro
# Processing Record 18 of Set 5 | senanga
# Processing Record 19 of Set 5 | camayenne
# Processing Record 20 of Set 5 | lhasa
# Processing Record 21 of Set 5 | altar
# Processing Record 22 of Set 5 | al 'amarah
# Processing Record 23 of Set 5 | dudinka
# Processing Record 24 of Set 5 | sao jose da coroa grande
# Processing Record 25 of Set 5 | bonthe
# Processing Record 26 of Set 5 | partinico
# Processing Record 27 of Set 5 | nuuk
# Processing Record 28 of Set 5 | xilin hot
# Processing Record 29 of Set 5 | aasiaat
# Processing Record 30 of Set 5 | teguise
# Processing Record 31 of Set 5 | choix
# Processing Record 32 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 33 of Set 5 | la reforma
# Processing Record 34 of Set 5 | muravlenko
# Processing Record 35 of Set 5 | ludvika
# Processing Record 36 of Set 5 | gamawa
# Processing Record 37 of Set 5 | pangoa
# Processing Record 38 of Set 5 | uturoa
# Processing Record 39 of Set 5 | horta
# Processing Record 40 of Set 5 | ghadamis
# Processing Record 41 of Set 5 | st. john's
# Processing Record 42 of Set 5 | ganshui
# Processing Record 43 of Set 5 | kingston
# Processing Record 44 of Set 5 | cide
# Processing Record 45 of Set 5 | mahibadhoo
# Processing Record 46 of Set 5 | talcahuano
# Processing Record 47 of Set 5 | sao joao da barra
# Processing Record 48 of Set 5 | tadine
# Processing Record 49 of Set 5 | cabo san lucas
# Processing Record 0 of Set 6 | opuwo
# Processing Record 1 of Set 6 | usogorsk
# Processing Record 2 of Set 6 | tobruk
# Processing Record 3 of Set 6 | umm kaddadah
# Processing Record 4 of Set 6 | howard springs
# Processing Record 5 of Set 6 | dunda
# Processing Record 6 of Set 6 | guatire
# Processing Record 7 of Set 6 | ust-nera
# Processing Record 8 of Set 6 | pontalina
# Processing Record 9 of Set 6 | nova sintra
# Processing Record 10 of Set 6 | caernarfon
# Processing Record 11 of Set 6 | slantsy
# Processing Record 12 of Set 6 | lebu
# Processing Record 13 of Set 6 | mirny
# Processing Record 14 of Set 6 | gusinoozyorsk
# Processing Record 15 of Set 6 | buzuluk
# Processing Record 16 of Set 6 | kaihua
# Processing Record 17 of Set 6 | hobyo
# Processing Record 18 of Set 6 | san carlos centro
# Processing Record 19 of Set 6 | hilo
# Processing Record 20 of Set 6 | arraial do cabo
# Processing Record 21 of Set 6 | marquette
# Processing Record 22 of Set 6 | mtambile
# Processing Record 23 of Set 6 | saint-philippe
# Processing Record 24 of Set 6 | barranca
# Processing Record 25 of Set 6 | ad dabbah
# Processing Record 26 of Set 6 | ancud
# Processing Record 27 of Set 6 | kampong speu
# Processing Record 28 of Set 6 | suntar
# Processing Record 29 of Set 6 | huadian
# Processing Record 30 of Set 6 | meulaboh
# Processing Record 31 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 32 of Set 6 | salalah
# Processing Record 33 of Set 6 | tabou
# Processing Record 34 of Set 6 | alaca
# Processing Record 35 of Set 6 | natal
# Processing Record 36 of Set 6 | gobabis
# Processing Record 37 of Set 6 | namibe
# Processing Record 38 of Set 6 | palmas
# Processing Record 39 of Set 6 | sandnessjoen
# Processing Record 40 of Set 6 | borzya
# Processing Record 41 of Set 6 | lao cai
# Processing Record 42 of Set 6 | acarau
# Processing Record 43 of Set 6 | sassandra
# Processing Record 44 of Set 6 | lazaro cardenas
# Processing Record 45 of Set 6 | ust'-uda
# Processing Record 46 of Set 6 | anadyr
# Processing Record 47 of Set 6 | sandakan
# Processing Record 48 of Set 6 | gaigeturi
# Processing Record 49 of Set 6 | taltal
# Processing Record 0 of Set 7 | qalat
# Processing Record 1 of Set 7 | malango
# Processing Record 2 of Set 7 | stephenville
# Processing Record 3 of Set 7 | wamba
# Processing Record 4 of Set 7 | rudbar
# Processing Record 5 of Set 7 | mandalgovi
# Processing Record 6 of Set 7 | istgah-e rah ahan-e garmsar
# Processing Record 7 of Set 7 | mantua
# Processing Record 8 of Set 7 | beni
# Processing Record 9 of Set 7 | awjilah
# Processing Record 10 of Set 7 | saiha
# Processing Record 11 of Set 7 | nur-sultan
# Processing Record 12 of Set 7 | plymouth
# Processing Record 13 of Set 7 | mar del plata
# Processing Record 14 of Set 7 | saint-denis
# Processing Record 15 of Set 7 | colonia
# Processing Record 16 of Set 7 | chernyshevskiy
# Processing Record 17 of Set 7 | nago
# Processing Record 18 of Set 7 | mount gambier
# Processing Record 19 of Set 7 | mabaruma
# Processing Record 20 of Set 7 | benguela
# Processing Record 21 of Set 7 | ocampo
# Processing Record 22 of Set 7 | luderitz
# Processing Record 23 of Set 7 | prince rupert
# Processing Record 24 of Set 7 | pushkinskiye gory
# Processing Record 25 of Set 7 | lodwar
# Processing Record 26 of Set 7 | crane
# Processing Record 27 of Set 7 | puerto ayora
# Processing Record 28 of Set 7 | peace river
# Processing Record 29 of Set 7 | cill airne
# Processing Record 30 of Set 7 | debre werk'
# Processing Record 31 of Set 7 | karatsu
# Processing Record 32 of Set 7 | cushing
# Processing Record 33 of Set 7 | lodja
# Processing Record 34 of Set 7 | marsabit
# Processing Record 35 of Set 7 | benghazi
# Processing Record 36 of Set 7 | quesnel
# Processing Record 37 of Set 7 | kenora
# Processing Record 38 of Set 7 | ipora
# Processing Record 39 of Set 7 | mizhhirya
# Processing Record 40 of Set 7 | mhamid
# Processing Record 41 of Set 7 | belousovka
# Processing Record 42 of Set 7 | petropavlivka
# Processing Record 43 of Set 7 | susuman
# Processing Record 44 of Set 7 | zaozersk
# Processing Record 45 of Set 7 | hammerfest
# Processing Record 46 of Set 7 | zakamensk
# Processing Record 47 of Set 7 | nadym
# Processing Record 48 of Set 7 | pawcatuck
# Processing Record 49 of Set 7 | weno
# Processing Record 0 of Set 8 | melekeok village
# Processing Record 1 of Set 8 | seward
# Processing Record 2 of Set 8 | codrington
# Processing Record 3 of Set 8 | smithers
# Processing Record 4 of Set 8 | north las vegas
# Processing Record 5 of Set 8 | nizhniy kuranakh
# Processing Record 6 of Set 8 | jogeva
# Processing Record 7 of Set 8 | timbiqui
# Processing Record 8 of Set 8 | queenstown
# Processing Record 9 of Set 8 | igarka
# Processing Record 10 of Set 8 | badger
# Processing Record 11 of Set 8 | orchard homes
# Processing Record 12 of Set 8 | amble
# Processing Record 13 of Set 8 | shohimardon
# Processing Record 14 of Set 8 | touros
# Processing Record 15 of Set 8 | arkhangel'sk
# Processing Record 16 of Set 8 | waspan
# Processing Record 17 of Set 8 | lihue
# Processing Record 18 of Set 8 | san luis de la loma
# Processing Record 19 of Set 8 | zykovo
# Processing Record 20 of Set 8 | burang
# Processing Record 21 of Set 8 | linares
# Processing Record 22 of Set 8 | barmer
# Processing Record 23 of Set 8 | licheng
# Processing Record 24 of Set 8 | port elizabeth
# Processing Record 25 of Set 8 | cockburn town
# Processing Record 26 of Set 8 | chatillon-sur-seine
# Processing Record 27 of Set 8 | rosarito
# Processing Record 28 of Set 8 | taft
# Processing Record 29 of Set 8 | bam
# Processing Record 30 of Set 8 | kavaratti
# Processing Record 31 of Set 8 | chu
# Processing Record 32 of Set 8 | lisala
# Processing Record 33 of Set 8 | cargados carajos
# City not found. Skipping...
# Processing Record 34 of Set 8 | piracanjuba
# Processing Record 35 of Set 8 | lagoa
# Processing Record 36 of Set 8 | pomuch
# Processing Record 37 of Set 8 | puerto aysen
# Processing Record 38 of Set 8 | tegina
# Processing Record 39 of Set 8 | akureyri
# Processing Record 40 of Set 8 | houma
# Processing Record 41 of Set 8 | sabang
# Processing Record 42 of Set 8 | tual
# Processing Record 43 of Set 8 | church hill
# Processing Record 44 of Set 8 | san antonio de pale
# Processing Record 45 of Set 8 | island harbour
# Processing Record 46 of Set 8 | kiruna
# Processing Record 47 of Set 8 | vuktyl
# Processing Record 48 of Set 8 | vernon
# Processing Record 49 of Set 8 | vardenis
# Processing Record 0 of Set 9 | olinda
# Processing Record 1 of Set 9 | tibati
# Processing Record 2 of Set 9 | atafu village
# Processing Record 3 of Set 9 | masterton
# Processing Record 4 of Set 9 | severo-yeniseyskiy
# Processing Record 5 of Set 9 | puerto baquerizo moreno
# Processing Record 6 of Set 9 | coahuayana de hidalgo
# Processing Record 7 of Set 9 | maralal
# Processing Record 8 of Set 9 | bowen
# Processing Record 9 of Set 9 | qui nhon
# Processing Record 10 of Set 9 | praia da vitoria
# Processing Record 11 of Set 9 | revda
# Processing Record 12 of Set 9 | catabola
# Processing Record 13 of Set 9 | kirakira
# Processing Record 14 of Set 9 | yanchep
# Processing Record 15 of Set 9 | tura
# Processing Record 16 of Set 9 | makar'yev
# Processing Record 17 of Set 9 | fort mcmurray
# Processing Record 18 of Set 9 | dolinsk
# Processing Record 19 of Set 9 | amargosa
# Processing Record 20 of Set 9 | okhotsk
# Processing Record 21 of Set 9 | znamenka
# Processing Record 22 of Set 9 | la penita de jaltomba
# Processing Record 23 of Set 9 | orai
# Processing Record 24 of Set 9 | fort bragg
# Processing Record 25 of Set 9 | hotan
# Processing Record 26 of Set 9 | mugia
# Processing Record 27 of Set 9 | otrokovice
# Processing Record 28 of Set 9 | kununurra
# Processing Record 29 of Set 9 | borivli
# Processing Record 30 of Set 9 | al bardiyah
# Processing Record 31 of Set 9 | dobje pri planini
# Processing Record 32 of Set 9 | taizhou
# Processing Record 33 of Set 9 | pierre
# Processing Record 34 of Set 9 | fisterra
# Processing Record 35 of Set 9 | milford haven
# Processing Record 36 of Set 9 | ilha de mocambique
# Processing Record 37 of Set 9 | puerto maldonado
# Processing Record 38 of Set 9 | cartagena del chaira
# Processing Record 39 of Set 9 | ola
# Processing Record 40 of Set 9 | cam pha mines
# Processing Record 41 of Set 9 | el porvenir
# Processing Record 42 of Set 9 | nieuw amsterdam
# Processing Record 43 of Set 9 | dukhan
# Processing Record 44 of Set 9 | les cayes
# Processing Record 45 of Set 9 | dunay
# Processing Record 46 of Set 9 | howrah
# Processing Record 47 of Set 9 | ibiza
# Processing Record 48 of Set 9 | sonoita
# Processing Record 49 of Set 9 | minas de marcona
# Processing Record 0 of Set 10 | gharavuti
# Processing Record 1 of Set 10 | bekovo
# Processing Record 2 of Set 10 | nar'yan-mar
# Processing Record 3 of Set 10 | kuta
# Processing Record 4 of Set 10 | seogwipo
# City not found. Skipping...
# Processing Record 5 of Set 10 | thurso
# Processing Record 6 of Set 10 | vrede
# Processing Record 7 of Set 10 | byron bay
# Processing Record 8 of Set 10 | manismata
# Processing Record 9 of Set 10 | emerald
# Processing Record 10 of Set 10 | gadzhiyevo
# Processing Record 11 of Set 10 | cadale
# Processing Record 12 of Set 10 | guercif
# Processing Record 13 of Set 10 | toumodi
# Processing Record 14 of Set 10 | belel
# Processing Record 15 of Set 10 | vila franca do campo
# Processing Record 16 of Set 10 | dasoguz
# Processing Record 17 of Set 10 | bagha purana
# Processing Record 18 of Set 10 | klyuchi
# Processing Record 19 of Set 10 | kapuskasing
# Processing Record 20 of Set 10 | acapulco de juarez
# Processing Record 21 of Set 10 | chulakkurgan
# Processing Record 22 of Set 10 | yangor
# City not found. Skipping...
# Processing Record 23 of Set 10 | kirkwood
# Processing Record 24 of Set 10 | haiku-pauwela
# Processing Record 25 of Set 10 | machico
# Processing Record 26 of Set 10 | murzuq
# Processing Record 27 of Set 10 | dryden
# Processing Record 28 of Set 10 | waingapu
# Processing Record 29 of Set 10 | hualien city
# Processing Record 30 of Set 10 | thinadhoo
# Processing Record 31 of Set 10 | tiquipaya
# Processing Record 32 of Set 10 | leiyang
# Processing Record 33 of Set 10 | amga
# Processing Record 34 of Set 10 | golfito
# Processing Record 35 of Set 10 | nicoya
# Processing Record 36 of Set 10 | kolosovka
# Processing Record 37 of Set 10 | loango
# Processing Record 38 of Set 10 | curvelo
# Processing Record 39 of Set 10 | feytiat
# Processing Record 40 of Set 10 | ain el bya
# Processing Record 41 of Set 10 | kruisfontein
# Processing Record 42 of Set 10 | broken hill
# Processing Record 43 of Set 10 | nova olimpia
# Processing Record 44 of Set 10 | bhamo
# Processing Record 45 of Set 10 | swakopmund
# Processing Record 46 of Set 10 | buka
# Processing Record 47 of Set 10 | ponta delgada
# Processing Record 48 of Set 10 | nikolayevsk-on-amure
# Processing Record 49 of Set 10 | estremoz
# Processing Record 0 of Set 11 | yuzhno-kurilsk
# Processing Record 1 of Set 11 | mount isa
# Processing Record 2 of Set 11 | neryungri
# Processing Record 3 of Set 11 | al-`ula
# City not found. Skipping...
# Processing Record 4 of Set 11 | keflavik
# Processing Record 5 of Set 11 | elmendorf air force base
# City not found. Skipping...
# Processing Record 6 of Set 11 | amahai
# Processing Record 7 of Set 11 | maumere
# Processing Record 8 of Set 11 | dar naim
# City not found. Skipping...
# Processing Record 9 of Set 11 | lata
# Processing Record 10 of Set 11 | jayapura
# Processing Record 11 of Set 11 | stuttgart
# Processing Record 12 of Set 11 | skovorodino
# Processing Record 13 of Set 11 | pachino
# Processing Record 14 of Set 11 | shirvan
# Processing Record 15 of Set 11 | nagqu
# Processing Record 16 of Set 11 | malanville
# Processing Record 17 of Set 11 | dolisie
# Processing Record 18 of Set 11 | slave lake
# Processing Record 19 of Set 11 | tromso
# Processing Record 20 of Set 11 | general conesa
# Processing Record 21 of Set 11 | mahanoro
# Processing Record 22 of Set 11 | mossel bay
# Processing Record 23 of Set 11 | ust'-ilimsk
# Processing Record 24 of Set 11 | bamboo flat
# Processing Record 25 of Set 11 | bushland beach
# City not found. Skipping...
# Processing Record 26 of Set 11 | george town
# Processing Record 27 of Set 11 | porto novo
# Processing Record 28 of Set 11 | demre
# Processing Record 29 of Set 11 | belyy yar
# Processing Record 30 of Set 11 | bargara
# City not found. Skipping...
# Processing Record 31 of Set 11 | singarayakonda
# Processing Record 32 of Set 11 | hola
# Processing Record 33 of Set 11 | sishilichengzi
# City not found. Skipping...
# Processing Record 34 of Set 11 | villa angela
# Processing Record 35 of Set 11 | axim
# Processing Record 36 of Set 11 | yarkovo
# Processing Record 37 of Set 11 | khandyga
# Processing Record 38 of Set 11 | cholpon-ata
# Processing Record 39 of Set 11 | stranraer
# Processing Record 40 of Set 11 | sao tome
# Processing Record 41 of Set 11 | otjimbingwe
# Processing Record 42 of Set 11 | cidreira
# Processing Record 43 of Set 11 | tamanrasset
# Processing Record 44 of Set 11 | coronel suarez
# Processing Record 45 of Set 11 | kidal
# Processing Record 46 of Set 11 | bodaybo
# Processing Record 47 of Set 11 | ujae
# Processing Record 48 of Set 11 | sinnar
# Processing Record 49 of Set 11 | ban nong wua so
# Processing Record 0 of Set 12 | barakani
# Processing Record 1 of Set 12 | anaconda
# Processing Record 2 of Set 12 | valparaiso
# Processing Record 3 of Set 12 | shrigonda
# Processing Record 4 of Set 12 | ilomantsi
# Processing Record 5 of Set 12 | port douglas
# Processing Record 6 of Set 12 | stara syniava
# Processing Record 7 of Set 12 | bundaberg north
# Processing Record 8 of Set 12 | knyaze-volkonskoye
# Processing Record 9 of Set 12 | shuangyang
# Processing Record 10 of Set 12 | mejit
# Processing Record 11 of Set 12 | daru
# Processing Record 12 of Set 12 | tarawa
# Processing Record 13 of Set 12 | piriapolis
# Processing Record 14 of Set 12 | bikenibeu village
# Processing Record 15 of Set 12 | alaghsas
# Processing Record 16 of Set 12 | opp
# Processing Record 17 of Set 12 | talara
# Processing Record 18 of Set 12 | essaouira
# Processing Record 19 of Set 12 | vilyuysk
# Processing Record 20 of Set 12 | polyarnyy
# Processing Record 21 of Set 12 | cabedelo
# Processing Record 22 of Set 12 | turkestan
# Processing Record 23 of Set 12 | tranovaho
# City not found. Skipping...
# Processing Record 24 of Set 12 | porto murtinho
# Processing Record 25 of Set 12 | marka
# Processing Record 26 of Set 12 | hadibu
# Processing Record 27 of Set 12 | pariquera acu
# Processing Record 28 of Set 12 | nova vicosa
# Processing Record 29 of Set 12 | ulsteinvik
# Processing Record 30 of Set 12 | we
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          561
# Lat           561
# Lng           561
# Max Temp      561
# Humidity      561
# Cloudiness    561
# Wind Speed    561
# Country       561
# Date          561
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                      fortuna  40.5982 -124.1573     15.52        63
# 1  edinburgh of the seven seas -37.0676  -12.3116     14.69        90
# 2                    shenkursk  62.1091   42.8960      1.24        84
# 3                   edmundston  47.3737  -68.3251      8.13        79
# 4             inarajan village  13.2736  144.7484     28.77        87
#
#    Cloudiness  Wind Speed Country        Date
# 0           0        5.14      US  1730938814
# 1          44        6.55      SH  1730938817
# 2          99        4.59      RU  1730938818
# 3         100        6.17      CA  1730938820
# 4          99        1.33      GU  1730938821

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                            fortuna  40.5982 -124.1573     15.52        63
# 1        edinburgh of the seven seas -37.0676  -12.3116     14.69        90
# 2                          shenkursk  62.1091   42.8960      1.24        84
# 3                         edmundston  47.3737  -68.3251      8.13        79
# 4                   inarajan village  13.2736  144.7484     28.77        87
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 0        5.14      US  1730938814
# 1                44        6.55      SH  1730938817
# 2                99        4.59      RU  1730938818
# 3               100        6.17      CA  1730938820
# 4                99        1.33      GU  1730938821

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], color="#0072BD", edgecolor='black', alpha=0.6 )

# Incorporate the other graph properties
plt.title('City Max Latitude vs. Temperature (2024-11-06)', )
plt.xlabel('Latitude', )
plt.ylabel('Max Temperature (°C)', )
plt.xlim(city_data_df['Lat'].min() - 5, city_data_df['Lat'].max() + 5)  
plt.ylim(city_data_df['Max Temp'].min() - 5, city_data_df['Max Temp'].max() + 5)  
plt.grid(True)  

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], color="#0072BD", edgecolor='black', alpha=0.6)

# Incorporate the other graph properties
plt.title('City Max Latitude vs. Humidity (2024-11-06)', )
plt.xlabel('Latitude', )
plt.ylabel('Humidity (%)', )
plt.xlim(city_data_df['Lat'].min() - 5, city_data_df['Lat'].max() + 5)  
plt.ylim(city_data_df['Humidity'].min() - 5, city_data_df['Humidity'].max() + 5)  
plt.grid(True)  

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], color="#0072BD", edgecolor='black', alpha=0.7)

# Incorporate the other graph properties
plt.title('City Max Latitude vs. Cloudiness (2024-11-06)', )
plt.xlabel('Latitude', )
plt.ylabel('Cloudiness (%)', )
plt.xlim(city_data_df['Lat'].min() - 5, city_data_df['Lat'].max() + 5)  
plt.ylim(city_data_df['Cloudiness'].min() - 5, city_data_df['Cloudiness'].max() + 5)  
plt.grid(True)  

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], color="#0072BD", edgecolor='black', alpha=0.6)

# Incorporate the other graph properties
plt.title('City Max Latitude vs. Wind Speed (2024-11-06)', )
plt.xlabel('Latitude', )
plt.ylabel('Wind Speed  (m/s)', )
plt.xlim(city_data_df['Lat'].min() - 5, city_data_df['Lat'].max() + 5)  
plt.ylim(city_data_df['Wind Speed'].min() - 1, city_data_df['Wind Speed'].max() + 1)  
plt.grid(True)  

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def linear_regression_plot(data, x_column, y_column):
    
    X = data[x_column]
    y = data[y_column]
    slope, intercept, r_value, p_value, std_err = linregress(X, y)
    y_pred = intercept + slope * X

     # Plot the regression line and creation of the scatter plot and regression line
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(X, y, color="#0072BD", label='Data Points' )
    plt.plot(X, y_pred, color='red', linewidth=2, label='Regression Line')

    # Get limits of the axes to determine a suitable position for the annotation
    xlim = plt.xlim()
    ylim = plt.ylim()
    x_position = xlim[0] + 0.05 * (xlim[1] - xlim[0])  
    y_center = (y.min() + y.max()) / 2
    
    # Labeling and showing the plot
    plt.title(f' Latitude vs {y_column}')
    plt.xlabel("Latitude", fontsize=12)
    plt.ylabel(y_column, fontsize=12)
    plt.annotate(line_eq,(x_position, y_center),fontsize=15,color="red")
    print(f"The r^2-value is: {r_value**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 fortuna  40.5982 -124.1573     15.52        63           0
# 2               shenkursk  62.1091   42.8960      1.24        84          99
# 3              edmundston  47.3737  -68.3251      8.13        79         100
# 4        inarajan village  13.2736  144.7484     28.77        87          99
# 6                qaqortoq  60.7167  -46.0333    -11.37        72           1
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      US  1730938814
# 2              4.59      RU  1730938818
# 3              6.17      CA  1730938820
# 4              1.33      GU  1730938821
# 6              3.55      GL  1730938824

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)

southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1        edinburgh of the seven seas -37.0676  -12.3116     14.69        90
# 5                          adamstown -25.0660 -130.1015     21.76        87
# 7                            ushuaia -54.8000  -68.3000      5.81        70
# 9                             osorno -40.5667  -73.1500     12.17        76
# 18                          waitangi -43.9535 -176.5597     13.33        88
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                44        6.55      SH  1730938817
# 5               100        6.53      PN  1730938822
# 7                40        5.14      AR  1730938602
# 9                 0        1.54      CL  1730938828
# 18               42        1.90      NZ  1730938839

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regression_plot(northern_hemi_df, 'Lat', 'Max Temp')
# Out:
# The r^2-value is: 0.7031306949056

# %%
# Linear regression on Southern Hemisphere
linear_regression_plot(southern_hemi_df, 'Lat', 'Max Temp')
# Out:
# The r^2-value is: 0.5067032552677196

# %% [markdown]
# ### LATITUDE VS MAX TEMP ANALYSIS
#
# **Discussion on linear relationship:**
#
# **Analysis of the northern hemisphere**
#
# In the case of the northern hemisphere we have a negative correlation between latitude and maximum temperature. This is to be expected, as regions closer to the equator are known to experience warmer temperatures than those at higher latitudes. In the graph we can see that as the cities move away from the equator the temperature decreases. Another contributing factor is the time of year, as we approach winter.
# The rsquared of 0.70 explains that approximately 70% of the temperature variability is due to the change in latitude, giving us a strong correlation.
#
# **Analysis of the southern hemisphere**
#
# In the case of the southern hemisphere we have a positive correlation between latitude and maximum temperature. As I said before, this is to be expected, since it is known that as the latitude approaches the equator, the temperature increases. In this case we have a graph that shows us the increase in temperature as cities approach the equator.
# The rsquare of 0.50 tells us that for our samples we have a temperature variance of 50% given the latitude, this can be explained by the season we are in when some cities begin to feel the winter sensation.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df, 'Lat', 'Humidity')
# Out:
# The r^2-value is: 0.07877496062382723

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df, 'Lat', 'Humidity')
# Out:
# The r^2-value is: 0.07664458877723652

# %% [markdown]
# ### LATITUDE VS HUMIDITY ANALYSIS
#
# **Discussion on linear relationship:**
#
# **Analysis of the northern hemisphere**
#
# In the case of the northern hemisphere we have a positive but not strong correlation trend since the data seem very dispersed. This is to be expected since humidity is more related to other factors such as altitude, proximity to the ocean, soil patterns, etc.
# The rsquared of 0.07 explains a very weak correlation as the data are further apart, telling us that there may be other factors affecting humidity rather than latitude alone.
#
# **Analysis of the southern hemisphere**
#
# In the case of the southern hemisphere, it is more or less the same as the northern hemisphere, we have a positive correlation trend, but not strong, since the data seems very scattered. Furthermore, this was to be expected since humidity is more related to other factors such as altitude, proximity to the ocean, weather patterns, soil patterns, etc.
# The rsquared is very similar to the previous graph, we have an rsquared of 0.076, which tells us a very weak correlation, since the data is further apart, which tells us that there are other factors affecting humidity instead of latitude by itself.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df, 'Lat', 'Cloudiness')
# Out:
# The r^2-value is: 0.06561812610557165

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df, 'Lat', 'Cloudiness')
# Out:
# The r^2-value is: 0.05970220089320159

# %% [markdown]
# ### LATITUDE VS CLOUDINESS ANALYSIS
#
# **Discussion on linear relationship:**
#
# **Analysis of the northern hemisphere**
#
# In this case we have a positive slope that tells us that for every 1 degree increase in latitude the expected cloudiness increases. This indicates a slight positive relationship between the increase in both factors. However, we have a very low r-squared value, which tells us that there may be other factors stronger than latitude to explain the increase in cloudiness.
# In the case of cloudiness, there may be other factors to take into account such as geographical characteristics given by urban environments, mountains, bodies of water and also the season in which northern cities tend to have a higher level of cloudiness.
#
# **Analysis of the southern hemisphere**
#
# In this case we also have a positive slope between cloudiness and decreasing latitude, but as in the previous case, there is a very weak rsquared value that tells us that these 2 factors are not strongly correlated, which can be explained by the factors mentioned above. in which cloudiness is more affected by other factors than latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df, 'Lat', 'Wind Speed')
# Out:
# The r^2-value is: 0.007168203140599195

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df, 'Lat', 'Wind Speed')
# Out:
# The r^2-value is: 0.004225054937078282

# %% [markdown]
# ### LATITUDE VS WIND SPEED ANALYSIS
#
# **Discussion on linear relationship:**
#
# **Analysis of the northern hemisphere**
#
# In this case we have a very low relationship between the parameters. We have an rsquared of 0.0072 which tells us that wind speed is probably explained by factors other than latitude.
# In the case of wind speed, the strong factor to take into account is the terrain of the city, if the terrain has mountains, valleys, bodies of water. These factors directly affect wind speed. Additionally, the season of the year is another important factor to consider, as winter storms can generate more wind speed than summer seasons.
#
# **Analysis of the southern hemisphere**
#
# In this case we also have a very weak relationship between the parameter. As explained previously, wind speed is more affected by other parameters than by the change in latitude, whether it is the southern or northern hemisphere.
